# %% [markdown]
# # PSUPR / PRMLS CA2

# %% [markdown]
# ### Team
# Kenneth Goh Chia Wei : A0198544N
# Tan Heng Han : A0198502B
# Raymond Ng Boon Cheong : A0198543R

# %% [markdown]
# ### CA2 Test Script
# Perform sentiment analysis on tweets from Apple event

# %%
import pandas as pd
import lxml
import re
import time

from bs4 import BeautifulSoup
from nltk.tokenize import WordPunctTokenizer

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model

# %% [markdown]
# ### Create a function for cleaning up tweets

# %%
def tweet_cleaner(text):
    # Init WordPunctTokenizer
    tok = WordPunctTokenizer()
    # create reg expression
    pat1 = r'@[A-Za-z0-9]+'
    pat2 = r'https?://[A-Za-z0-9./]+'
    combined_pat = r'|'.join((pat1, pat2))
    # Use beautiful soup to decode html to text
    soup = BeautifulSoup(text, 'lxml')
    souped = soup.get_text()
    # strip text using regular expression
    stripped = re.sub(combined_pat, '', souped)
    try:
        clean = stripped.decode("utf-8-sig").replace(u"\ufffd", "?")
    except:
        clean = stripped
    # strip to letters only
    letters_only = re.sub("[^a-zA-Z]", " ", clean)
    # remove retweets handle
    removed_rt = re.sub('RT ','',letters_only)
    # set to lower case for all characters
    lower_case = removed_rt.lower()
    # Use tokenize to remove whitespace created by letters_only above
    words = tok.tokenize(lower_case)
    return (" ".join(words)).strip()

# %% [markdown]
# ### Load Apple event data from csv

# %%
file = '..\\dataset\\tweets_appleEvent.csv'
df = pd.read_csv(file)

# %%
df.shape
# Out:
# (1000, 14)

# %%
df.head()
# Out:
#                                                 text weekday month  day  hour  \
# 0  RT @timmaughan: Back in 2014 I visited Inner M...     Tue   Sep   10    16
# 1  RT @beebomco: iPhone 11 launches tonight. You ...     Tue   Sep   10    16
# 2  RT @CNET: Tune into the #AppleEvent today at:\...     Tue   Sep   10    16
# 3  RT @BraJinglez: Apple has added a new payment ...     Tue   Sep   10    16
# 4  RT @mauobenol: iPhone 11 launches tomorrow! An...     Tue   Sep   10    16
#
#    has_hashtag  has_url  fav_count  is_reply  retweet_count  followers  \
# 0            0        0          0         0              4       3086
# 1            1        0          0         0           1716         14
# 2            1        0          0         0             84        418
# 3            1        0          0         0           5943        848
# 4            1        0          0         0           4094         48
#
#    following                    user   screen_name
# 0       1288  Roderick McKie Esquire      rodmckie
# 1         90          God Kizaru🐝🇩🇴🍑   GodKizaruRD
# 2       2700                on/off ™  EstherLamarr
# 3        352              Yemi Stark  yemiscofield
# 4         69                 𝗸𝗮𝗶𝗹𝗲𝗲。     _seoularr

# %%
# Keep only tweets and its label
text = df['text']
text.head()
# Out:
# 0    RT @timmaughan: Back in 2014 I visited Inner M...
# 1    RT @beebomco: iPhone 11 launches tonight. You ...
# 2    RT @CNET: Tune into the #AppleEvent today at:\...
# 3    RT @BraJinglez: Apple has added a new payment ...
# 4    RT @mauobenol: iPhone 11 launches tomorrow! An...
# Name: text, dtype: object

# %% [markdown]
# ### Clean up tweets

# %%
# %%time
cleaned_tweets = []
for tweet in text:
    cleaned_tweets.append(tweet_cleaner(tweet))
print(cleaned_tweets[:5])
print(f'Tweets total: {len(cleaned_tweets)}')
# Out:
# ['back in i visited inner mongolia and this toxic run off lake that s a byproduct of rare earth refining want to help', 'iphone launches tonight you ready iphone iphonexi appleevent apple', 'tune into the appleevent today at am pdt pm cdt pm edt pm bst pm ist wednesday', 'apple has added a new payment option for iphone appleevent', 'iphone launches tomorrow and i still have an iphone s appleevent']
# Tweets total: 1000
# Wall time: 247 ms

# %% [markdown]
# ### Rejoin all tweets and drop duplicate tweets

# %%
appleTweets = pd.DataFrame({'text': cleaned_tweets})
appleTweets.drop_duplicates(subset='text', inplace=True, keep='first')

# %%
appleTweets.shape
# Out:
# (328, 1)

# %%
appleTweets.head()
# Out:
#                                                 text
# 0  back in i visited inner mongolia and this toxi...
# 1  iphone launches tonight you ready iphone iphon...
# 2  tune into the appleevent today at am pdt pm cd...
# 3  apple has added a new payment option for iphon...
# 4  iphone launches tomorrow and i still have an i...

# %% [markdown]
# ### Load pre-train model

# %%
model = load_model('train_model')
# Out:
# WARNING:tensorflow:From D:\Anaconda3\envs\prmlsca2\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From D:\Anaconda3\envs\prmlsca2\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From D:\Anaconda3\envs\prmlsca2\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From D:\Anaconda3\envs\prmlsca2\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From D:\Anaconda3\envs\prmlsca2\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From D:\Anaconda3\envs\prmlsca2\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From D:\Anaconda3\envs\prmlsca2\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From D:\Anaconda3\envs\prmlsca2\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From D:\Anaconda3\envs\prmlsca2\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %% [markdown]
# ### Import trained tokenizer

# %%
import pickle
with open('tokenizer.pickle', 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
labels = ['happy', 'sad', 'angry']

def label_sentiment(scores):
    maxScore = 0
    maxIdx = 0
    for i in range(len(scores)):
        if scores[i] > maxScore:
            maxScore = scores[i]
            maxIdx = i
    return maxIdx

def predict(text):
    # Tokenize text
    x_test = pad_sequences(tokenizer.texts_to_sequences([text]), maxlen=300)
    # Predict
    scores = model.predict([x_test])[0]
    # Decode sentiment
    lblIdx = label_sentiment(scores)
    return labels[lblIdx], scores

# %% [markdown]
# ### Perform sentiment analysis on tweets

# %%
# %%time
for txt in appleTweets.text:
    lbl, scores = predict(txt)
    print(f'Tweet: {txt}')
    print(f'Predicted Sentiment: {lbl}, Scores: {scores}\n')
# Out:
# Tweet: back in i visited inner mongolia and this toxic run off lake that s a byproduct of rare earth refining want to help
# Predicted Sentiment: angry, Scores: [0.33241805 0.31148502 0.35609692]
#
# Tweet: iphone launches tonight you ready iphone iphonexi appleevent apple
# Predicted Sentiment: angry, Scores: [0.33072525 0.30553904 0.3637357 ]
#
# Tweet: tune into the appleevent today at am pdt pm cdt pm edt pm bst pm ist wednesday
# Predicted Sentiment: happy, Scores: [0.6092634  0.22173415 0.16900244]
#
# Tweet: apple has added a new payment option for iphone appleevent
# Predicted Sentiment: happy, Scores: [0.35939816 0.32045642 0.32014543]
#
# Tweet: iphone launches tomorrow and i still have an iphone s appleevent
# Predicted Sentiment: happy, Scores: [0.34559858 0.32390696 0.33049443]
#
# Tweet: rawkz i m confused did apple just launched a new gas cooker or is this the iphone appleevent
# Predicted Sentiment: happy, Scores: [0.3501239  0.32317123 0.32670483]
#
# Tweet: cupertino calling join us today at a m pdt to watch the appleevent at
# Predicted Sentiment: happy, Scores: [0.37485054 0.32197964 0.30316982]
#
# Tweet: i can t believe we re already at iphone like when did that happen appleevent
# Predicted Sentiment: happy, Scores: [0.391979  0.3094319 0.2985891]
#
# Tweet: this trailer was exclusively shot with the iphone you can see a large improvement in the camera quality of iphones apple
# Predicted Sentiment: happy, Scores: [0.5045291  0.2752628  0.22020811]
#
# Tweet: after years i m gonna miss today s appleevent keynote oh well i m due for an upgrade nevertheless
# Predicted Sentiment: sad, Scores: [0.16227756 0.664341   0.17338142]
#
# Tweet: new iphones an apple watch update a one more thing surprise unveil we re at apple park to watch today s
# Predicted Sentiment: happy, Scores: [0.35585934 0.30381933 0.34032133]
#
# Tweet: me getting ready to preorder the new iphone without having the slightest idea of its new features appleevent
# Predicted Sentiment: happy, Scores: [0.442837   0.29854    0.25862294]
#
# Tweet: apple event media arrive ahead of kick off appleevent
# Predicted Sentiment: happy, Scores: [0.64222085 0.21002123 0.14775792]
#
# Tweet: officl the new iphones appleevent apple iphone
# Predicted Sentiment: happy, Scores: [0.4017255  0.31113818 0.2871363 ]
#
# Tweet: wasn t too impressed with the the iphone reveal at the appleevent thoughts
# Predicted Sentiment: angry, Scores: [0.30692467 0.29196864 0.40110666]
#
# Tweet: as big apple users we re hugely interested in the new iphone it will be amazing for recording filming and ed
# Predicted Sentiment: happy, Scores: [0.6058198  0.22156443 0.1726158 ]
#
# Tweet: good morning meatbags it is i the esqueda are you ready for an appleevent
# Predicted Sentiment: sad, Scores: [0.31877533 0.36495078 0.31627393]
#
# Tweet: guys be ready appleevent
# Predicted Sentiment: happy, Scores: [0.34232914 0.323107   0.33456385]
#
# Tweet: apple announcement appleevent iphone youtube
# Predicted Sentiment: happy, Scores: [0.3665121  0.3181933  0.31529462]
#
# Tweet: does the new iphone really have all those holes appleevent
# Predicted Sentiment: happy, Scores: [0.34732592 0.32350817 0.3291659 ]
#
# Tweet: apple s iphone launch event appleevent iphone
# Predicted Sentiment: happy, Scores: [0.46782118 0.28683314 0.24534571]
#
# Tweet: when android users brag about tech they already had to iphone users appleevent
# Predicted Sentiment: happy, Scores: [0.42431727 0.3060083  0.26967448]
#
# Tweet: meet the new iphone xi appleevent
# Predicted Sentiment: happy, Scores: [0.41867295 0.31488547 0.26644164]
#
# Tweet: this is what u look like if u take a picture with iphone pro max appleevent
# Predicted Sentiment: happy, Scores: [0.44826433 0.29426724 0.25746846]
#
# Tweet: this is the view inside a gorgeous moneylineac sportsbook it s filmed with an iphone scola fred mcleod have
# Predicted Sentiment: angry, Scores: [0.32346964 0.315329   0.3612014 ]
#
# Tweet: before and after buying iphone appleevent
# Predicted Sentiment: happy, Scores: [0.34486908 0.32397676 0.33115417]
#
# Tweet: haters will say it is fake but they are right it s naa real iphone appleevent
# Predicted Sentiment: angry, Scores: [0.33365512 0.32887232 0.33747253]
#
# Tweet: bye bye apple go samsunt appleevent
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: the new iphone looks great appleevent
# Predicted Sentiment: happy, Scores: [0.41075164 0.30950606 0.2797423 ]
#
# Tweet: i realized it was the day of the appleevent because my phone started lagging for no reason
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: hr left appleevent c
# Predicted Sentiment: happy, Scores: [0.34475476 0.32394058 0.33130467]
#
# Tweet: squaddddd samsung users trying to figure out how the new iphone works iphone appleevent
# Predicted Sentiment: happy, Scores: [0.38691053 0.3121064  0.30098304]
#
# Tweet: baby s first appleevent
# Predicted Sentiment: happy, Scores: [0.36193174 0.27660298 0.36146528]
#
# Tweet: appleevent wanting the new iphone my bank account http
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: excitement is building appleevent apple iphone
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: some ladies vagina rn as appleevent launches the new iphone whereas it got unforgivable beatings from
# Predicted Sentiment: happy, Scores: [0.4374361  0.29815516 0.26440874]
#
# Tweet: event starting soon appleevent
# Predicted Sentiment: happy, Scores: [0.59606785 0.22788525 0.17604691]
#
# Tweet: i m actually very excited to watch the event not in a safari browser today will be the first time the compa
# Predicted Sentiment: happy, Scores: [0.53356564 0.24723127 0.21920305]
#
# Tweet: apple event prediction this is the one where mac os makes a comeback appleevent apple macos
# Predicted Sentiment: happy, Scores: [0.5041071  0.27052763 0.22536524]
#
# Tweet: i ve been waiting for so long appleevent
# Predicted Sentiment: happy, Scores: [0.35375345 0.32176888 0.32447767]
#
# Tweet: appleevent me making plans my bank account to buy the apple iphone
# Predicted Sentiment: happy, Scores: [0.37931827 0.3109377  0.309744  ]
#
# Tweet: hold on a sec what s this appleevent
# Predicted Sentiment: happy, Scores: [0.36005688 0.32186997 0.31807312]
#
# Tweet: new iphone will have spiner function appleevent
# Predicted Sentiment: happy, Scores: [0.42239672 0.3093764  0.26822686]
#
# Tweet: mafia middle class people trying to buy iphone appleevent
# Predicted Sentiment: happy, Scores: [0.39433032 0.3046632  0.3010065 ]
#
# Tweet: samsung huawei killing apple appleevent
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: the lull before the storm appleevent
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: me buying airpods after the event appleevent
# Predicted Sentiment: happy, Scores: [0.5222569  0.26336014 0.21438293]
#
# Tweet: omg love you can t wait for the appleevent with iphone
# Predicted Sentiment: sad, Scores: [0.31053942 0.38772395 0.3017366 ]
#
# Tweet: apple s phil schiller entering the steve jobs theater in cupertino this morning for the appleevent
# Predicted Sentiment: happy, Scores: [0.35818595 0.32344127 0.3183728 ]
#
# Tweet: cupertino calling join us on september at am myt to watch the appleevent at
# Predicted Sentiment: happy, Scores: [0.41398558 0.31595325 0.27006122]
#
# Tweet: not long until tonights appleevent we can t wait to see the latest from apple
# Predicted Sentiment: happy, Scores: [0.44985002 0.296345   0.25380495]
#
# Tweet: apple iphone be like appleevent iphone
# Predicted Sentiment: happy, Scores: [0.36012822 0.31737715 0.32249463]
#
# Tweet: since iphone is out i can finally convince my parents to buy me the iphone x appleevent
# Predicted Sentiment: happy, Scores: [0.37745634 0.3084082  0.3141355 ]
#
# Tweet: we out here appleevent starts in one hour
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: i present the online apple store with t minutes until appleevent
# Predicted Sentiment: angry, Scores: [0.28508785 0.24362391 0.47128826]
#
# Tweet: the new appleevent iphone is coming out me using my android
# Predicted Sentiment: happy, Scores: [0.3537762  0.3221519  0.32407194]
#
# Tweet: apple iphone camera is better than ever android user we had that already appleevent
# Predicted Sentiment: happy, Scores: [0.3500417  0.3227824  0.32717597]
#
# Tweet: umiii appleevent iphone me what s the difference between the iphone pro and the iphone pro max apple employee https
# Predicted Sentiment: happy, Scores: [0.3962109  0.30651757 0.29727155]
#
# Tweet: in years replaced
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: damn the iphone is appleevent
# Predicted Sentiment: happy, Scores: [0.36931697 0.31706503 0.313618  ]
#
# Tweet: apple releases credit card right before announcing new products wonder why appleevent
# Predicted Sentiment: happy, Scores: [0.50726205 0.25545615 0.23728183]
#
# Tweet: i expected to see craziness in appleevent specialty with iphone
# Predicted Sentiment: happy, Scores: [0.39854217 0.31355602 0.28790185]
#
# Tweet: download iphone event apple logo wallpapers for iphone ipad and mac appleevent
# Predicted Sentiment: happy, Scores: [0.447458   0.29047188 0.26207006]
#
# Tweet: in honor of today s appleevent orig published sept
# Predicted Sentiment: angry, Scores: [0.20897996 0.20672481 0.5842952 ]
#
# Tweet: nick ackerman don t try to buy an iphone or anything online right now almost there iphone iphone appleevent
# Predicted Sentiment: happy, Scores: [0.37793    0.31906632 0.30300367]
#
# Tweet: here we go iphone appleevent
# Predicted Sentiment: happy, Scores: [0.3465976  0.32421762 0.3291848 ]
#
# Tweet: i m ready for this appleevent
# Predicted Sentiment: happy, Scores: [0.34784818 0.3240337  0.32811812]
#
# Tweet: nick ackerman apple is the king of hype so many complain about the prices the lack of innovation and how same old same old however
# Predicted Sentiment: happy, Scores: [0.4118354  0.31667003 0.27149457]
#
# Tweet: camera market is now affected by the mindsets of millennial who now prefer to have iphone rather than committing to b
# Predicted Sentiment: happy, Scores: [0.37918332 0.30644155 0.31437513]
#
# Tweet: steve jobs theatre appleevent
# Predicted Sentiment: happy, Scores: [0.36087576 0.3226455  0.31647876]
#
# Tweet: everybodies iphone after goes on sale appleevent iphone
# Predicted Sentiment: happy, Scores: [0.36234108 0.31639707 0.32126185]
#
# Tweet: can t wait for nirmala sitharaman to announce that people aren t buying iphones because they re using pco appleevent
# Predicted Sentiment: happy, Scores: [0.38672584 0.32221282 0.29106134]
#
# Tweet: maybe if apple did this iphone appleevent
# Predicted Sentiment: happy, Scores: [0.37325266 0.32246223 0.30428514]
#
# Tweet: mypov live and in person appleevent
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: nick ackerman i really hope rumors were wrong and there is something surprising at the event tired of rumors and media knowing ever
# Predicted Sentiment: happy, Scores: [0.4606082  0.3164717  0.22292003]
#
# Tweet: dealing with health insurance issues is not how i imagined spending my appleevent day
# Predicted Sentiment: happy, Scores: [0.3614598  0.29348472 0.34505552]
#
# Tweet: hoping to see some good memes tmrw other than silly old kidney ones already those tripod jokes are not so good jus
# Predicted Sentiment: angry, Scores: [0.26392955 0.26278374 0.47328675]
#
# Tweet: breaking just introduce the new payment method for purchase of iphone iphone pro iphone
# Predicted Sentiment: angry, Scores: [0.35802972 0.27635553 0.36561474]
#
# Tweet: here s why today s appleevent is historic live streamed on youtube for the first time ever htt
# Predicted Sentiment: happy, Scores: [0.34776393 0.32840654 0.32382947]
#
# Tweet: at least this makes sense appleevent
# Predicted Sentiment: happy, Scores: [0.36514345 0.31893668 0.3159199 ]
#
# Tweet: ready for the appleevent please let there be airpods announced
# Predicted Sentiment: happy, Scores: [0.45931745 0.26466262 0.27601987]
#
# Tweet: appleevent waiting for new iphone my bank account https
# Predicted Sentiment: happy, Scores: [0.37537152 0.31737587 0.3072526 ]
#
# Tweet: there s only one thing we almost love as much as salesforce and that s we re all excited for tonight s appleevent
# Predicted Sentiment: happy, Scores: [0.36724126 0.31824628 0.31451246]
#
# Tweet: who s excited for the appleevent i am pretty darn excited this time a ton of leaks later ready to see how the products f
# Predicted Sentiment: happy, Scores: [0.39793676 0.31456196 0.28750128]
#
# Tweet: yall hyping up a phone that hasnt changed for the third year in a row and will think they did something revolutionary lol appleevent
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: iphones iphone appleevent
# Predicted Sentiment: happy, Scores: [0.34486908 0.32397676 0.33115417]
#
# Tweet: lohan when they announce the price of the new iphone appleevent
# Predicted Sentiment: happy, Scores: [0.40182963 0.31487826 0.2832921 ]
#
# Tweet: from iphone and applewatchseries to tim cook s vision of software and services here s what to expect at today
# Predicted Sentiment: angry, Scores: [0.3391415  0.31288618 0.34797236]
#
# Tweet: iphone they said appleevent
# Predicted Sentiment: angry, Scores: [0.31997728 0.3152676  0.36475506]
#
# Tweet: tomorrow appleevent which one you feel best iphone iphone max iphone pro
# Predicted Sentiment: happy, Scores: [0.3791538  0.31433254 0.30651367]
#
# Tweet: apple event will be live on youtube appleevent
# Predicted Sentiment: happy, Scores: [0.5537745  0.24547462 0.20075089]
#
# Tweet: short of a surprise release of a round apple watch i doubt there will be any shut up and take my money moments at today s appleevent
# Predicted Sentiment: happy, Scores: [0.3904745  0.30734405 0.30218145]
#
# Tweet: nick ackerman i ve noticed in the past few years mainstream media starting to cover apple events a lot more since they ve noticed yo
# Predicted Sentiment: happy, Scores: [0.4347228  0.30784902 0.25742814]
#
# Tweet: appleevent me explaining to my kidney that i really need the new iphone my kidney https
# Predicted Sentiment: sad, Scores: [0.28182057 0.44177517 0.27640426]
#
# Tweet: i really want to attend an appleevent in person
# Predicted Sentiment: sad, Scores: [0.26129237 0.47228312 0.26642454]
#
# Tweet: apple store is down new iphones are being announced at an event this afternoon appleevent
# Predicted Sentiment: happy, Scores: [0.37072343 0.32073927 0.30853727]
#
# Tweet: holy cow appleevent in mins
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: the s live blog is now up if you want to check out real time coverage of the appleevent
# Predicted Sentiment: happy, Scores: [0.51313734 0.26377606 0.22308658]
#
# Tweet: psal here is the link to today s appleevent
# Predicted Sentiment: angry, Scores: [0.35502166 0.2833655  0.36161286]
#
# Tweet: all set for the appleevent
# Predicted Sentiment: happy, Scores: [0.34772357 0.32405734 0.32821912]
#
# Tweet: apple event today appleevent iphone apple
# Predicted Sentiment: happy, Scores: [0.60197836 0.2252155  0.17280614]
#
# Tweet: i feel like each year apple is just trying to make the worst fucking possible phone and see how much of us actual
# Predicted Sentiment: happy, Scores: [0.36671454 0.30854565 0.32473978]
#
# Tweet: retweet this to win the new iphone appleevent
# Predicted Sentiment: happy, Scores: [0.4715707  0.28434533 0.24408402]
#
# Tweet: in years these will be the new iphones lol appleevent
# Predicted Sentiment: happy, Scores: [0.36314833 0.32076064 0.31609106]
#
# Tweet: be our guest be our guest put our products to the test put your pass around your neck cherie and we provide the best
# Predicted Sentiment: angry, Scores: [0.34196925 0.29638657 0.36164418]
#
# Tweet: less than hour left for appleevent to kick off stay tuned to our updates as we ll be bringing you live tweets and cover
# Predicted Sentiment: angry, Scores: [0.29777953 0.25109977 0.45112073]
#
# Tweet: good morning and welcome to applepark new announcements coming soon appleevent apple park
# Predicted Sentiment: sad, Scores: [0.33687803 0.34269172 0.32043025]
#
# Tweet: awan new payment option for iphone i need both of kidneys of my friend mention your friend appleevent
# Predicted Sentiment: happy, Scores: [0.40183464 0.30358803 0.29457742]
#
# Tweet: two years from now that iphone you re dieing for will be cheap just be patient appleevent
# Predicted Sentiment: happy, Scores: [0.8345693  0.10207589 0.06335485]
#
# Tweet: i m exciting to launch ios system appleevent
# Predicted Sentiment: happy, Scores: [0.40171742 0.31114405 0.28713855]
#
# Tweet: less than an hour appleevent
# Predicted Sentiment: angry, Scores: [0.22739375 0.21228413 0.56032217]
#
# Tweet: me trying to find a loan to buy the new iphone appleevent
# Predicted Sentiment: happy, Scores: [0.42332935 0.30342785 0.27324286]
#
# Tweet: documents show that the development of an ar headset has continued any updates to share appleevent
# Predicted Sentiment: happy, Scores: [0.4032955  0.30531648 0.29138803]
#
# Tweet: lowkey excited appleevent
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: the release of the iphone means other iphones will drop in price that s where we come in iphone here we come for y
# Predicted Sentiment: angry, Scores: [0.32744232 0.30799454 0.36456317]
#
# Tweet: triple lenses it s absurd don t believe me ask the nerds they can argue they can grapple after all miss this is a
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: apple isn t messing around today check the url appleevent
# Predicted Sentiment: happy, Scores: [0.6692564  0.18997423 0.14076936]
#
# Tweet: i m still using a iphone se so sorry appleevent iphone is a no from me i m out
# Predicted Sentiment: angry, Scores: [0.16402724 0.12249377 0.713479  ]
#
# Tweet: kidney jokes are coming appleevent
# Predicted Sentiment: sad, Scores: [0.26231942 0.48614833 0.2515322 ]
#
# Tweet: folks ohhhh the new iphone coming out me knowing i still got the plus appleevent
# Predicted Sentiment: happy, Scores: [0.48230094 0.2863462  0.23135287]
#
# Tweet: damn heard that this video was shot from an iphone appleevent
# Predicted Sentiment: happy, Scores: [0.4010206  0.30487347 0.29410595]
#
# Tweet: in preparation for the appleevent we are giving away tons of iphones along with cash and bts albums to win like and retwe
# Predicted Sentiment: happy, Scores: [0.47658396 0.28294125 0.2404748 ]
#
# Tweet: buy me an iphone pro and i m all yours iphone appleevent
# Predicted Sentiment: happy, Scores: [0.50350046 0.26531905 0.23118053]
#
# Tweet: anyone up for the appleevent i am already ready for it tho hope they don t ruine it this time with stupid pricing as they always do
# Predicted Sentiment: angry, Scores: [0.3010066  0.2894707  0.40952268]
#
# Tweet: wisso sorry but it s super ugly appleevent
# Predicted Sentiment: angry, Scores: [0.18078224 0.18531884 0.6338989 ]
#
# Tweet: appleevent tim cook we introduce apple water audience
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: happy appleevent day
# Predicted Sentiment: sad, Scores: [0.14366536 0.6908005  0.16553412]
#
# Tweet: infinite loopiness appleevent
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: google i would like iphonese waiting forever excite i hope for iphonese i m waiting eternally appleevent
# Predicted Sentiment: angry, Scores: [0.2937376  0.29294652 0.41331583]
#
# Tweet: as sad as you may think this is i love and every appleevent i couldn t switch to even if
# Predicted Sentiment: sad, Scores: [0.00159807 0.99531144 0.0030905 ]
#
# Tweet: getting ready for the appleevent
# Predicted Sentiment: happy, Scores: [0.3557379  0.3235466  0.32071555]
#
# Tweet: apple fans getting excited just thinking about the appleevent
# Predicted Sentiment: happy, Scores: [0.5144776  0.26356453 0.2219578 ]
#
# Tweet: girls can easily find there way to buy iphone by allowing a rich guy to eat there work or liberate them poor guys li
# Predicted Sentiment: happy, Scores: [0.4020304  0.30676275 0.29120687]
#
# Tweet: the new iphones appleevent apple iphone
# Predicted Sentiment: happy, Scores: [0.4017255  0.31113818 0.2871363 ]
#
# Tweet: i m convinced the secret to career success at apple is skinny jeans all the cool kids are wearing them appleevent
# Predicted Sentiment: happy, Scores: [0.3623374  0.32723856 0.31042406]
#
# Tweet: is the appleevent streamed on appletv
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: the appleevent starts in an hour follow our liveblog here
# Predicted Sentiment: angry, Scores: [0.33881238 0.31797364 0.34321398]
#
# Tweet: appleevent day is here get ready to learn more about the iphone
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: appleevent day my geeky apple ass is living
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: the apple event is so close who s ready i know i am also who is upgrading to the new phone and why let me know appleevent
# Predicted Sentiment: happy, Scores: [0.6084344  0.21841814 0.17314744]
#
# Tweet: appleinsider has arrived at applepark to witness apple s launch of new iphone models among other products appleevent
# Predicted Sentiment: happy, Scores: [0.49946597 0.26776958 0.23276444]
#
# Tweet: iphone rumor we re expecting a budget successor to the iphone xr a midrange flagship like the iphone xs and a supersize model
# Predicted Sentiment: happy, Scores: [0.36013064 0.30597416 0.33389518]
#
# Tweet: stay tuned for event appleevent retweeetplease
# Predicted Sentiment: happy, Scores: [0.45565236 0.28806397 0.25628367]
#
# Tweet: who s watching the appleevent
# Predicted Sentiment: happy, Scores: [0.35973498 0.3238482  0.31641683]
#
# Tweet: scenes from inside the steve jobs theater with an hour to go for the appleevent to start
# Predicted Sentiment: happy, Scores: [0.37450707 0.3095004  0.3159925 ]
#
# Tweet: snake after appleevent me try to buy iphone
# Predicted Sentiment: happy, Scores: [0.37865904 0.31079322 0.3105477 ]
#
# Tweet: today appleevent
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: ipad concept appleevent
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: qt iphone is overrated as long as you can breathe and communicate trust you re good appleevent
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: picoftheday from ut of dadra and nagar haveli ganapativisarjan muharramulharam wearehindustan
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: clapped appleevent
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: appleevent lmfao
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: under kg new macbook that s all i want appleevent
# Predicted Sentiment: happy, Scores: [0.34852082 0.32315618 0.32832304]
#
# Tweet: a simple graph of my interest in the appleevent
# Predicted Sentiment: happy, Scores: [0.3458553  0.32428688 0.3298578 ]
#
# Tweet: i m dead appleevent
# Predicted Sentiment: happy, Scores: [0.34779412 0.32404393 0.3281619 ]
#
# Tweet: ugly looking people who can t afford iphone se are calling iphone ugly let that sink in appleevent
# Predicted Sentiment: happy, Scores: [0.41370264 0.2893954  0.296902  ]
#
# Tweet: appleevent looking forward for pricing of products
# Predicted Sentiment: happy, Scores: [0.37096462 0.32019573 0.30883962]
#
# Tweet: getting ready to go in and the crush of people forms appleevent
# Predicted Sentiment: happy, Scores: [0.34768155 0.32395062 0.32836786]
#
# Tweet: looking for the appleevent livestream now you can watch it on youtube plus your ios ma
# Predicted Sentiment: happy, Scores: [0.5316461  0.2577689  0.21058503]
#
# Tweet: why the fuck does the new iphone need three holes appleevent
# Predicted Sentiment: happy, Scores: [0.3912181 0.3100687 0.2987132]
#
# Tweet: tic tac tic tac keynoteapple keynote appleevent iphone live
# Predicted Sentiment: happy, Scores: [0.34442848 0.32385212 0.33171937]
#
# Tweet: squaddddd when she buys you a samsung instead of an iphone iphone appleevent
# Predicted Sentiment: happy, Scores: [0.36599007 0.3216689  0.31234106]
#
# Tweet: i know that is a generic statement but the xs and xs max camera didn t really move the needle in terms of innovatio
# Predicted Sentiment: angry, Scores: [0.31070462 0.3398903  0.3494051 ]
#
# Tweet: cupertino calling join us today at pm ist to watch the appleevent at
# Predicted Sentiment: happy, Scores: [0.4046017  0.31256002 0.28283826]
#
# Tweet: iphone pro and pro max look ugly the iphone looks the best compared to them appleevent
# Predicted Sentiment: happy, Scores: [0.41339442 0.30880794 0.27779764]
#
# Tweet: apple has never heard of shades oh my head appleevent cooked
# Predicted Sentiment: happy, Scores: [0.35148454 0.3279746  0.3205409 ]
#
# Tweet: i want to stay up at am for appleevent the event ends at am i got class at am i have to wake up an hour befo
# Predicted Sentiment: happy, Scores: [0.4293079  0.3047703  0.26592186]
#
# Tweet: mypov the anticipation appleevent new phones iphone pro watch appletv waterproof airpods security features
# Predicted Sentiment: happy, Scores: [0.47354153 0.28422752 0.242231  ]
#
# Tweet: hold up appleevent
# Predicted Sentiment: happy, Scores: [0.36537868 0.31952935 0.31509194]
#
# Tweet: keller team switzerland appleevent
# Predicted Sentiment: happy, Scores: [0.47317377 0.2841701  0.24265613]
#
# Tweet: bitch a new iphone already iphone my broke ass staying with the iphone till it brakes down appleevent
# Predicted Sentiment: happy, Scores: [0.4421984  0.29479825 0.26300335]
#
# Tweet: at the steve jobs theater for the appleevent
# Predicted Sentiment: happy, Scores: [0.36087576 0.3226455  0.31647876]
#
# Tweet: very excited for the apple event here in about minutes apple appleevent iphone iphone onemorething
# Predicted Sentiment: happy, Scores: [0.35519707 0.32211185 0.3226911 ]
#
# Tweet: i m so very excited for tonight one more hour to go been watching the apple events since hope to be a deve
# Predicted Sentiment: happy, Scores: [0.43902758 0.28540826 0.27556416]
#
# Tweet: for the first time since i will not be getting the new iphone all the rumors are so underwhelming to me
# Predicted Sentiment: happy, Scores: [0.4273195  0.31755826 0.2551222 ]
#
# Tweet: i ll let the hype play itself out and watch the appleevent at night on a certain youtube video titled maybe apple event in mins
# Predicted Sentiment: happy, Scores: [0.7032644  0.16946967 0.12726599]
#
# Tweet: getting ready this morning knowing we re all about to fall for whatever bare minimum products apple announces next
# Predicted Sentiment: happy, Scores: [0.35009858 0.32535225 0.32454917]
#
# Tweet: i think this is the first year since they became available that i haven t downloaded the public beta appleevent
# Predicted Sentiment: happy, Scores: [0.3837597  0.31644976 0.2997905 ]
#
# Tweet: after every appleevent apple iphone android iphone
# Predicted Sentiment: happy, Scores: [0.40176284 0.34647655 0.25176057]
#
# Tweet: series apple watch incoming appleevent
# Predicted Sentiment: happy, Scores: [0.452098   0.29559815 0.2523038 ]
#
# Tweet: getting busy over here appleevent
# Predicted Sentiment: happy, Scores: [0.34817335 0.32322866 0.328598  ]
#
# Tweet: apple is set to unveil new iphones today here s how and when to watch appleevent
# Predicted Sentiment: happy, Scores: [0.3760067  0.31676966 0.3072236 ]
#
# Tweet: appleevent dude can someone tweet me live updates because i m at work but i need to know what s going down
# Predicted Sentiment: happy, Scores: [0.3477238  0.32359025 0.3286859 ]
#
# Tweet: alright i ain t staying up for appleevent nothing new will come out tonight it ll be a whole load of its our f
# Predicted Sentiment: angry, Scores: [0.2944243  0.33663967 0.36893603]
#
# Tweet: im going to be drinking a massive amount of wine during the apple event today i bet you won t see that on cnet
# Predicted Sentiment: happy, Scores: [0.48282486 0.2796507  0.23752442]
#
# Tweet: appleevent iphone launches me to my mom plz mom after listening ipho
# Predicted Sentiment: sad, Scores: [0.15081348 0.6764638  0.17272274]
#
# Tweet: are y all feeling these the main reason i be upgrading is because of the camera appleevent iphone
# Predicted Sentiment: happy, Scores: [0.34842244 0.32275167 0.3288259 ]
#
# Tweet: im buying it anyway so i dont care how it looks appleevent
# Predicted Sentiment: happy, Scores: [0.34653953 0.3229993  0.33046117]
#
# Tweet: not long to go now appleevent iphone
# Predicted Sentiment: angry, Scores: [0.33897358 0.3210958  0.33993065]
#
# Tweet: top top top kd nba k appleevent
# Predicted Sentiment: happy, Scores: [0.7835395  0.13427988 0.08218072]
#
# Tweet: going live at pm et with and to discuss our appleevent predictions and hype you d
# Predicted Sentiment: happy, Scores: [0.61134577 0.21736512 0.17128907]
#
# Tweet: how many of y all sleep with your iphone practically in your hand see if your phone sleep habits are the no
# Predicted Sentiment: happy, Scores: [0.36777732 0.29685953 0.33536318]
#
# Tweet: get ready for a nutty appleevent today lots of big announcements incoming
# Predicted Sentiment: happy, Scores: [0.73559636 0.15786175 0.10654185]
#
# Tweet: the steve jobs theater for iphone appleevent
# Predicted Sentiment: happy, Scores: [0.37178785 0.3190778  0.3091344 ]
#
# Tweet: damn straight up forgot that today s the appleevent i have to ignore
# Predicted Sentiment: happy, Scores: [0.34671727 0.32254446 0.33073828]
#
# Tweet: the phrase designed in california assembled in china now makes sense at the appleevent
# Predicted Sentiment: happy, Scores: [0.38121247 0.31054258 0.30824494]
#
# Tweet: welcome apple park appleevent
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: it s apple time appleevent
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: me seeing all the new iphones and loptos me broke af appleevent iphone
# Predicted Sentiment: happy, Scores: [0.35042524 0.322192   0.3273827 ]
#
# Tweet: team switzerland appleevent
# Predicted Sentiment: happy, Scores: [0.47317377 0.2841701  0.24265613]
#
# Tweet: circle boys nodey play o iphone appleevent
# Predicted Sentiment: happy, Scores: [0.41853926 0.29472885 0.2867319 ]
#
# Tweet: iphone appleevent this is when apple s iphone models will launch in india via
# Predicted Sentiment: happy, Scores: [0.4699652  0.2828317  0.24720316]
#
# Tweet: this is how steve jobs introduced the first iphone and the rest is history appleevent
# Predicted Sentiment: angry, Scores: [0.3321228  0.29586768 0.3720095 ]
#
# Tweet: cool awaiting for your video of appleevent
# Predicted Sentiment: sad, Scores: [0.3242466  0.41321117 0.26254228]
#
# Tweet: iphone launch live latest announcements from apple s keynote event appleevent
# Predicted Sentiment: happy, Scores: [0.42287126 0.30210575 0.275023  ]
#
# Tweet: what will comes in appleevent iphone iphone pro iphone pro max apple watch series public software upd
# Predicted Sentiment: happy, Scores: [0.52845544 0.2643572  0.20718734]
#
# Tweet: back in i visited inner mongolia and this toxic run off lake that s a byproduct of rare earth refining want
# Predicted Sentiment: angry, Scores: [0.33764553 0.3111589  0.35119557]
#
# Tweet: less than a hour to go before the appleevent and we ve reached a milestone here on twitter followers i d like t
# Predicted Sentiment: angry, Scores: [0.33486435 0.21007372 0.45506194]
#
# Tweet: how to watch today s appleevent now on youtube
# Predicted Sentiment: happy, Scores: [0.47682595 0.28186643 0.24130757]
#
# Tweet: watch weird monkey rapist rapes his family members monkey rapist news insane memes
# Predicted Sentiment: happy, Scores: [0.4024134  0.37157637 0.22601017]
#
# Tweet: tic tac tic tac appleevent
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: minutes until the appleevent
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: then sell kidney spend money and buy iphones now follow traffic rules save money and buy iphones appleevent ipho
# Predicted Sentiment: happy, Scores: [0.41057467 0.26249117 0.3269341 ]
#
# Tweet: one hour to go till appleevent unveils it s latest iphone and in no time people will start repeating the kidney jokes
# Predicted Sentiment: angry, Scores: [0.30536047 0.3035889  0.39105064]
#
# Tweet: the prices for the xs and xs max already dropped appleevent iphone
# Predicted Sentiment: happy, Scores: [0.35630918 0.3195382  0.32415256]
#
# Tweet: apple iphone live launch event apple special event september appleevent iphone
# Predicted Sentiment: happy, Scores: [0.621656   0.20785944 0.1704846 ]
#
# Tweet: leaked photo of the iphone team figuring out how much to charge for the newest model appleevent iphone
# Predicted Sentiment: happy, Scores: [0.5438131  0.25368926 0.20249762]
#
# Tweet: i m hoping for a new watch appleevent
# Predicted Sentiment: happy, Scores: [0.43125197 0.31079617 0.25795186]
#
# Tweet: you guys ready for the new iphone with cameras appleevent
# Predicted Sentiment: happy, Scores: [0.38230684 0.32494238 0.2927508 ]
#
# Tweet: honored to have our mobile app newsela student chosen from over million apps as the app store s app of the day want to jo
# Predicted Sentiment: happy, Scores: [0.34156185 0.31767073 0.34076744]
#
# Tweet: kol my heart skipped iphone bbnaija tuesdaymotivation appleevent lupitanyongo
# Predicted Sentiment: angry, Scores: [0.0474211  0.0327484  0.91983056]
#
# Tweet: do you know when apple s tipping point was appleevent appleevent
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: the triple lens camera in iphone is to snap your body spirit and soul at a go appleevent
# Predicted Sentiment: happy, Scores: [0.34668013 0.32425445 0.32906547]
#
# Tweet: not expecting much for the iphone but with apple you never know appleevent
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: today is the day appleevent
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: omg the iphone looks so good watch til the end it looks amazing appleevent
# Predicted Sentiment: happy, Scores: [0.37079993 0.31340057 0.31579956]
#
# Tweet: nngamers tuning in at pm et appleevent
# Predicted Sentiment: happy, Scores: [0.7476563  0.14887068 0.10347299]
#
# Tweet: me and my bank account looking at each other after willing to buy iphone appleevent
# Predicted Sentiment: happy, Scores: [0.396572   0.31277853 0.2906495 ]
#
# Tweet: gonna use my mb for this appleevent storobonus
# Predicted Sentiment: happy, Scores: [0.44915533 0.27529317 0.27555144]
#
# Tweet: appleevent memes are so funny
# Predicted Sentiment: sad, Scores: [0.03405063 0.91488737 0.05106207]
#
# Tweet: new new new new everything new and must watch iphone appleevent
# Predicted Sentiment: happy, Scores: [0.3791911  0.31725734 0.30355158]
#
# Tweet: cnetlive appleevent what we want to know is the camera going to help me make my feature films with great quality
# Predicted Sentiment: happy, Scores: [0.4287395 0.3016276 0.2696329]
#
# Tweet: appleevent is just tim cook going on stage to tell us the rumors are true with a flashy power point presentation
# Predicted Sentiment: happy, Scores: [0.41488126 0.3057361  0.27938262]
#
# Tweet: if u have never purchased iphone ever iphone appleevent
# Predicted Sentiment: happy, Scores: [0.35008958 0.32268205 0.32722834]
#
# Tweet: iphone when it heats up appleevent apple
# Predicted Sentiment: happy, Scores: [0.3418612  0.32228708 0.33585173]
#
# Tweet: what do we know about the iphone so far it will come with a triple lens camera several new colours and is predict
# Predicted Sentiment: happy, Scores: [0.34819666 0.3238094  0.32799396]
#
# Tweet: it s coming soon tap below to get reminders and news around the appleevent watch it live on september at a m pdt on
# Predicted Sentiment: happy, Scores: [0.43283916 0.3028531  0.26430777]
#
# Tweet: android users appleevent
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: after every appleevent
# Predicted Sentiment: happy, Scores: [0.38941064 0.36118826 0.24940109]
#
# Tweet: i am getting a new phone baby appleevent
# Predicted Sentiment: happy, Scores: [0.37023044 0.3190325  0.3107371 ]
#
# Tweet: cupertino apple there s a buzz inside the steve jobs theater today and we have live blogging the
# Predicted Sentiment: happy, Scores: [0.3542468  0.3208452  0.32490802]
#
# Tweet: the appleevent starts in less than hour here s how to watch it live
# Predicted Sentiment: angry, Scores: [0.28292552 0.2624973  0.45457712]
#
# Tweet: camera market is now affected by the mindsets of millennial who now prefer to have iphone rather than committing t
# Predicted Sentiment: happy, Scores: [0.39315522 0.31262812 0.29421663]
#
# Tweet: find my rolls apps into find my iphone find my friends maps gets better apple is teasing apple arcade and remind
# Predicted Sentiment: happy, Scores: [0.3460114  0.32323125 0.3307573 ]
#
# Tweet: even if you aren t getting iphone today s appleevent will reveal the ios release date something everyone can appre
# Predicted Sentiment: happy, Scores: [0.3630268  0.31768653 0.31928673]
#
# Tweet: stunning morning at apple park will be bringing you all the news live from the appleevent
# Predicted Sentiment: sad, Scores: [0.31973016 0.37824416 0.30202568]
#
# Tweet: iphone appleevent before and after buying iphone
# Predicted Sentiment: angry, Scores: [0.3299484  0.31159008 0.35846153]
#
# Tweet: excited for the appleevent but still
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: apple users to android users appleevent
# Predicted Sentiment: angry, Scores: [0.33265132 0.3184032  0.34894544]
#
# Tweet: i don t want to believe those ugly images are the new set of iphones so i m patiently waiting for the appleevent iphone
# Predicted Sentiment: happy, Scores: [0.3871401  0.3046283  0.30823165]
#
# Tweet: er if this is real people with trypophobia are going to have a rough time appleevent
# Predicted Sentiment: happy, Scores: [0.46352875 0.29249486 0.24397644]
#
# Tweet: big appleevent today the new iphones are going to be polarizing for sure
# Predicted Sentiment: happy, Scores: [0.6514229  0.20607285 0.14250425]
#
# Tweet: new iphone is coming appleevent iphone iphone pro
# Predicted Sentiment: happy, Scores: [0.45685765 0.2912149  0.2519275 ]
#
# Tweet: things that didn t exist before the first iphone or years ago airbnb spotify lyft pinterest slack snapchat instagra
# Predicted Sentiment: happy, Scores: [0.3563464  0.32588738 0.31776625]
#
# Tweet: honored to have our mobile app newsela student chosen from over million apps as the app store s app of the day
# Predicted Sentiment: happy, Scores: [0.35032785 0.32161185 0.32806027]
#
# Tweet: it better not be trash appleevent
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: t minutes to the appleevent polishing my watch iphone ipad and mac mini to remind me not to go out and pre order everything tonight
# Predicted Sentiment: angry, Scores: [0.32332817 0.31362572 0.3630461 ]
#
# Tweet: we just gonna wait for the new iphone appleevent
# Predicted Sentiment: happy, Scores: [0.3651534  0.32312185 0.3117247 ]
#
# Tweet: broke appleevent woke
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: whenever apple launches new iphone appleevent iphone
# Predicted Sentiment: happy, Scores: [0.38391498 0.3181977  0.29788738]
#
# Tweet: appleevent iphone apple stream
# Predicted Sentiment: happy, Scores: [0.3418612  0.32228708 0.33585173]
#
# Tweet: oh yess i heard that iphone gonna be the main sponsor for taeyong s mv debut appleevent
# Predicted Sentiment: sad, Scores: [0.29062122 0.41963014 0.28974864]
#
# Tweet: one of the annual questions paying attention in class or live tweeting appleevent right now i don t need a new a
# Predicted Sentiment: happy, Scores: [0.39029118 0.30563262 0.3040762 ]
#
# Tweet: ready for the appleevent please let there be airpods announced today
# Predicted Sentiment: happy, Scores: [0.46661445 0.2696052  0.2637804 ]
#
# Tweet: twitter trends pm sep worldsuicidepreventionday tuesdaythoughts appleevent top
# Predicted Sentiment: happy, Scores: [0.64165694 0.19272187 0.16562119]
#
# Tweet: less than a hour to go appleevent
# Predicted Sentiment: angry, Scores: [0.2646525  0.2454375  0.48991004]
#
# Tweet: appleevent apple has taken down its online store ahead the company s annual hardware event iphone
# Predicted Sentiment: happy, Scores: [0.45325074 0.2841307  0.26261857]
#
# Tweet: i m pretty excited about the new ipads appleevent
# Predicted Sentiment: angry, Scores: [0.3305446  0.31805304 0.35140234]
#
# Tweet: can t the guests at appleevent boo when they launch the same old iphones with just minor updates this getting annoying e
# Predicted Sentiment: happy, Scores: [0.4639377  0.2750839  0.26097834]
#
# Tweet: arewa hello guys we have this apple macbook air going down co i gb ram hd graphics price k kindly bless
# Predicted Sentiment: happy, Scores: [0.3853402  0.30436972 0.31029013]
#
# Tweet: i really need a new phone please keep them based on your old pricing appleevent
# Predicted Sentiment: happy, Scores: [0.33959356 0.332447   0.32795948]
#
# Tweet: payment for iphone iphone appleevent
# Predicted Sentiment: happy, Scores: [0.37849176 0.32076868 0.30073962]
#
# Tweet: who would like to win an ipadair this month one lucky winner will receive this fantastic prize at the end of the mont
# Predicted Sentiment: angry, Scores: [0.35528326 0.27409384 0.37062293]
#
# Tweet: my iphone battery is acting up and my ipad is all crashy the night before the appleevent
# Predicted Sentiment: happy, Scores: [0.345131   0.32105523 0.33381376]
#
# Tweet: chikna android user at an appleevent
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: karini get ready for the next big appleevent apple iphone iphone iphonexs iphonex still unofficial
# Predicted Sentiment: happy, Scores: [0.56529516 0.25062966 0.18407516]
#
# Tweet: remembering steve jobs ijustreallymisshim spidermanfarfromhome appleevent
# Predicted Sentiment: happy, Scores: [0.3475588  0.3242758  0.32816544]
#
# Tweet: mag with just under an hour until until the annual keynote speech we look at apple s payment innovations since appleev
# Predicted Sentiment: happy, Scores: [0.3564508  0.32024908 0.3233001 ]
#
# Tweet: the secret is out invited me as a vip to the appleevent i m so excited firsttime
# Predicted Sentiment: happy, Scores: [0.37156805 0.3169184  0.31151357]
#
# Tweet: appleevent trending android users
# Predicted Sentiment: happy, Scores: [0.34933233 0.32375115 0.32691652]
#
# Tweet: one hour till the apple event appleevent
# Predicted Sentiment: happy, Scores: [0.5368326  0.25625458 0.20691283]
#
# Tweet: in years iphone replaced
# Predicted Sentiment: happy, Scores: [0.346518   0.3243118  0.32917023]
#
# Tweet: you know when there s an appleevent people will make following jokes dude apple has a kidney payment option hehe
# Predicted Sentiment: sad, Scores: [0.30808502 0.424363   0.26755196]
#
# Tweet: if apple launches a bundle of appletvplus applearcade applemusic i would be so down to get it appleevent
# Predicted Sentiment: happy, Scores: [0.34968543 0.3222958  0.32801872]
#
# Tweet: here is what i love about attending an appleevent you get to see all of the awesome tech stars you watch on youtube li
# Predicted Sentiment: happy, Scores: [0.413046   0.30363557 0.28331846]
#
# Tweet: strieb me i actually can t imagine what an exciting new iphone would look like apple neither can we appleevent
# Predicted Sentiment: sad, Scores: [0.33265167 0.34763208 0.3197163 ]
#
# Tweet: appleevent phone predictions double sided fullscreen phone phone folded from wallet size to tablet size
# Predicted Sentiment: angry, Scores: [0.3343416  0.31384933 0.35180905]
#
# Tweet: about minutes later appleevent
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: hour to go guys hype appleevent
# Predicted Sentiment: angry, Scores: [0.30265477 0.3077381  0.38960707]
#
# Tweet: same appleevent
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: hello i m tohn jitor a time traveller and this is iphone appleevent
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: should i stay up to watch appleevent or stay up to voice chat with my friends on discord
# Predicted Sentiment: happy, Scores: [0.35900423 0.32078    0.3202158 ]
#
# Tweet: nobody iphone appleevent
# Predicted Sentiment: angry, Scores: [0.33900455 0.3219612  0.33903432]
#
# Tweet: with just under an hour until until the annual keynote speech we look at apple s payment innovations since
# Predicted Sentiment: happy, Scores: [0.3564508  0.32024908 0.3233001 ]
#
# Tweet: mypov live appleevent
# Predicted Sentiment: happy, Scores: [0.3462113  0.32428738 0.32950133]
#
# Tweet: appleevent i m excited can t wait to pre order the new iphone
# Predicted Sentiment: happy, Scores: [0.42944083 0.30603737 0.26452175]
#
# Tweet: gearing up and getting ready for appleevent at stevejobstheatre my new macbook isn t here yet so will be watch
# Predicted Sentiment: happy, Scores: [0.36756426 0.32457662 0.3078591 ]
#
# Tweet: second appleevent i ll miss due to being on a plane next time i ll get a flight i ll bet on the date it ought to work
# Predicted Sentiment: happy, Scores: [0.42148155 0.30152923 0.27698925]
#
# Tweet: squaddddd apple we will be releasing the brand new super expensive iphone with no new changes iphone appleevent my dumb
# Predicted Sentiment: happy, Scores: [0.4583994  0.29109964 0.25050098]
#
# Tweet: why does the new iphone camera look a fidget spinner iphone appleevent
# Predicted Sentiment: happy, Scores: [0.37649453 0.33084065 0.2926649 ]
#
# Tweet: the three eyed raven appleevent
# Predicted Sentiment: happy, Scores: [0.3469997  0.31327075 0.33972955]
#
# Tweet: comrades appleevent happening soon and here are leeks of new airpods
# Predicted Sentiment: happy, Scores: [0.374993   0.31845716 0.30654985]
#
# Tweet: appleevent three mp cameras shooting pictures that look like you ve attached different lenses to the same camera if that ha
# Predicted Sentiment: angry, Scores: [0.28556287 0.3079109  0.4065262 ]
#
# Tweet: and we meet again full of energy for the appleevent
# Predicted Sentiment: happy, Scores: [0.35932368 0.32902208 0.31165427]
#
# Tweet: iphone to huawei did i win huawei p pro iphone appleevent
# Predicted Sentiment: happy, Scores: [0.5810189  0.22410773 0.19487342]
#
# Tweet: the only thing left to announce at an appleevent is affordable prices
# Predicted Sentiment: happy, Scores: [0.35931075 0.3189226  0.3217667 ]
#
# Tweet: do they invite android users appleevent
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: can t believe i have to work while the appleevent is on
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: stuck at work hoping i can get back for the start of appleevent all i really want to see at least wise is l
# Predicted Sentiment: happy, Scores: [0.41445896 0.28997892 0.29556212]
#
# Tweet: counting down till it starts appleevent
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: i m loving the new camera features appleevent
# Predicted Sentiment: sad, Scores: [0.29098687 0.39961419 0.30939904]
#
# Tweet: when everyone is talking about iphone but you are still using iphone with a cracked screen appleevent
# Predicted Sentiment: happy, Scores: [0.53632283 0.24635595 0.21732122]
#
# Tweet: me at the apple store shop after today s appleevent
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: cnetlive what price range do you think the new apple products will be appleevent
# Predicted Sentiment: happy, Scores: [0.39976415 0.3136213  0.28661448]
#
# Tweet: being the most powerful person in the world does not mean that you are the most loved person in the world
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: at the apple iphone appleevent applepark
# Predicted Sentiment: happy, Scores: [0.365058   0.3224639  0.31247807]
#
# Tweet: tr apple has added a new payment option for iphone appleevent
# Predicted Sentiment: happy, Scores: [0.35939816 0.32045642 0.32014543]
#
# Tweet: i m more interested in the series because my series took seconds to launch shazam first world problem indeed appleevent
# Predicted Sentiment: happy, Scores: [0.500733   0.26000255 0.23926435]
#
# Tweet: the views are going so fast omg thanks appleevent
# Predicted Sentiment: happy, Scores: [0.34363833 0.3236524  0.3327093 ]
#
# Tweet: supersaf without black glasses is just safwan all pumped for the appleevent
# Predicted Sentiment: angry, Scores: [0.36078116 0.27370125 0.36551765]
#
# Tweet: one hour to go appleevent special iphone thewalk roleplaying games adventure thedestination s tom lucy
# Predicted Sentiment: happy, Scores: [0.34383452 0.321642   0.33452347]
#
# Tweet: me i actually can t imagine what an exciting new iphone would look like apple neither can we appleevent
# Predicted Sentiment: sad, Scores: [0.33265167 0.34763208 0.3197163 ]
#
# Tweet: this high quality video was recorded with the new iphone that s being presented at the appleevent iphone
# Predicted Sentiment: happy, Scores: [0.5195271  0.22745106 0.2530219 ]
#
# Tweet: soviets with help from twitter bots thank north carolina bathrooms what could go wrong truth realnews
# Predicted Sentiment: happy, Scores: [0.42828175 0.3062005  0.2655178 ]
#
# Tweet: these apple event tweets are killer lmao appleevent
# Predicted Sentiment: happy, Scores: [0.53334546 0.2564984  0.21015616]
#
# Tweet: don t have money to buy the upcoming apple iphones but still i will watch the apple event dear and
# Predicted Sentiment: happy, Scores: [0.5720282  0.24482973 0.1831421 ]
#
# Tweet: it s apple time appleevent is starting in an hour
# Predicted Sentiment: happy, Scores: [0.34610054 0.3243634  0.32953605]
#
# Tweet: is down which means one thing the new iphone is coming i need to sell that kidney whatever else it takes
# Predicted Sentiment: happy, Scores: [0.38337106 0.30863422 0.30799478]
#
# Wall time: 1min 9s
